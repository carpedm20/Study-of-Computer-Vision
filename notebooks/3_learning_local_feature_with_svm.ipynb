# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy.ndimage import zoom
from skimage.io import imread
from skimage import color, feature, filter
from skimage.transform import resize

from skimage.io import imread

import random
import glob
import pyprind
import multiprocessing as mp
import time
from random import shuffle

SIZE = (30,15)
#TEST = True
TEST = False

fig = plt.figure(figsize=SIZE)

FOOD_PATH = "/home/carpedm20/data/food100/"


def oversample(images, crop_dims):
    """
    code from https://github.com/BVLC/caffe/blob/master/python/caffe/io.py
    
    Crop images into the four corners, center, and their mirrored versions.

    Take
    image: iterable of (H x W x K) ndarrays
    crop_dims: (height, width) tuple for the crops.

    Give
    crops: (10*N x H x W x K) ndarray of crops for number of inputs N.
    """
    # Dimensions and center.
    im_shape = np.array(images[0].shape)
    crop_dims = np.array(crop_dims)
    im_center = im_shape[:2] / 2.0

    # Make crop coordinates
    h_indices = (0, im_shape[0] - crop_dims[0])
    w_indices = (0, im_shape[1] - crop_dims[1])
    crops_ix = np.empty((5, 4), dtype=int)
    curr = 0
    for i in h_indices:
        for j in w_indices:
            crops_ix[curr] = (i, j, i + crop_dims[0], j + crop_dims[1])
            curr += 1
    crops_ix[4] = np.tile(im_center, (1, 2)) + np.concatenate([
        -crop_dims / 2.0,
         crop_dims / 2.0
    ])
    crops_ix = np.tile(crops_ix, (2, 1))

    # Extract crops
    crops = np.empty((10 * len(images), crop_dims[0], crop_dims[1],
                            im_shape[-1]), dtype=np.float32)
    ix = 0
    for im in images:
        for crop in crops_ix:
            crops[ix] = im[crop[0]:crop[2], crop[1]:crop[3], :]
            ix += 1
        crops[ix-5:ix] = crops[ix-5:ix, :, ::-1, :]  # flip for mirrors
    return crops


def resize_image(im, new_dims, interp_order=1):
    """
    code from https://github.com/BVLC/caffe/blob/master/python/caffe/io.py
    
    Resize an image array with interpolation.

    Take
    im: (H x W x K) ndarray
    new_dims: (height, width) tuple of new dimensions.
    interp_order: interpolation order, default is linear.

    Give
    im: resized ndarray with shape (new_dims[0], new_dims[1], K)
    """
    if im.shape[-1] == 1 or im.shape[-1] == 3:
        # skimage is fast but only understands {1,3} channel images in [0, 1].
        im_min, im_max = im.min(), im.max()
        im_std = (im - im_min) / (im_max - im_min)
        resized_std = resize(im_std, new_dims, order=interp_order)
        resized_im = resized_std * (im_max - im_min) + im_min
    else:
        # ndimage interpolates anything but more slowly.
        scale = tuple(np.array(new_dims) / np.array(im.shape[:2]))
        resized_im = zoom(im, scale + (1,), order=interp_order)
    return resized_im.astype(np.float32)

# %%
from sklearn.cross_validation import train_test_split
import os

if TEST:
    food1 = glob.glob("/home/carpedm20/data/food100/1/*.jpg")
    print len(food1)
    food2 = glob.glob("/home/carpedm20/data/food100/36/*.jpg")
    print len(food2)
    food3 = glob.glob("/home/carpedm20/data/food100/23/*.jpg")
    print len(food3)
    foods = food1 + food2 + food3
else:
    foods = glob.glob("/home/carpedm20/data/food100/*/*.jpg")
    
#foods = glob.glob("/home/carpedm20/data/food100/1/*.jpg")

def build_labels(foods):
    new_foods = []
    for food in foods:
        food_label = food[len(FOOD_PATH):].split("/")[0]
        new_foods.append((food, food_label))
    return new_foods

foods = build_labels(foods)

train, test = train_test_split(foods, test_size=0.33, random_state=42)

shuffle(train)
shuffle(test)

print "train : %s" % len(train)
print "test : %s" % len(test)


train_labels = [int(x[1]) for x in train]
test_labels = [int(x[1]) for x in test]

#print train
# Out:
# train : 9621
# test : 4740

# %%
import Image

if TEST:
    COUNT = 20
else:
    COUNT = len(foods)

fs = []
hogs = []

orientations = 9
cell = 16
block = 3

####################
# Training phase
####################
foods = train

MIN_WIDTH = MIN_HEIGHT = 100000

def get_foods(foods, limit=COUNT):
    bar = pyprind.ProgBar(limit, monitor=True)
    for idx, food in enumerate(foods[:limit]):
        bar.update()
        img = imread(food[0])
        
        try:
            yield color.rgb2gray(img)
        except:
            continue
            
def get_cropped_foods(foods, height, width, limit=COUNT):
    bar = pyprind.ProgBar(limit, monitor=True)
    for idx, food in enumerate(foods[:limit]):
        bar.update()
        img = imread(food[0])
        img = resize_image(img, (height, width))
        
        try:
            yield color.rgb2gray(img)
        except:
            continue

"""
for food in get_foods(foods):
    height = food.shape[0]
    width = food.shape[1]
    
    if height < MIN_HEIGHT:
        MIN_HEIGHT = height
    if width < MIN_WIDTH:
        MIN_WIDTH = width
        
print "MIN WIDTH : %s" % MIN_WIDTH
print "MIN HEIGHT : %s" % MIN_HEIGHT
"""

def build_feature_vecture(foods):
    for food in get_cropped_foods(foods, 256, 256):
        f = feature.hog(food,
                        orientations=orientations,
                        pixels_per_cell=(cell, cell),
                        cells_per_block=(block, block))
                        #visualise=True)
        #dimension = len(f)
        fs.append((f.ravel()).tolist())
        #hogs.append(hog)

"""
def build_feature_matrix(foods):
    pool = multiprocessing.Pool(processes=4)
    res = pool.map(build_feature_vecture, foods)
    return np.array(res)
"""

#build_feature_matrix(foods)
build_feature_vecture(foods)
# Out:
# 0%                          100%
# [                              ]
# [#                             ]
#  | ETA[sec]: 666.516
# [##                            ]
#  | ETA[sec]: 644.485
# [###                           ]
#  | ETA[sec]: 607.720
# [####                          ]
#  | ETA[sec]: 579.059
# [#####                         ]
#  | ETA[sec]: 545.776
# [######                        ]
#  | ETA[sec]: 514.261
# [#######                       ]
#  | ETA[sec]: 496.395
# [########                      ]
#  | ETA[sec]: 480.538
# [#########                     ]
#  | ETA[sec]: 453.776
# [##########                    ]
#  | ETA[sec]: 434.541
# [###########                   ]
#  | ETA[sec]: 430.181
# [############                  ]
#  | ETA[sec]: 410.331
# [#############                 ]
#  | ETA[sec]: 387.479
# [##############                ]
#  | ETA[sec]: 364.940
# [###############               ]
#  | ETA[sec]: 340.945
# [################              ]
#  | ETA[sec]: 316.893
# [#################             ]
#  | ETA[sec]: 293.559
# [##################            ]
#  | ETA[sec]: 270.265
# [###################           ]
#  | ETA[sec]: 246.992
# [####################          ]
#  | ETA[sec]: 223.638
# [#####################         ]
#  | ETA[sec]: 200.888
# [######################        ]
#  | ETA[sec]: 178.690
# [#######################       ]
#  | ETA[sec]: 155.984
# [########################      ]
#  | ETA[sec]: 133.886
# [#########################     ]
#  | ETA[sec]: 111.927
# [##########################    ]
#  | ETA[sec]: 89.740
# [###########################   ]
#  | ETA[sec]: 67.363
# [############################  ]
#  | ETA[sec]: 44.953
# [############################# ]
#  | ETA[sec]: 22.508
# [##############################]
#  | ETA[sec]: 0.000
# [##############################]
#  | ETA[sec]: 0.000
# Total time elapsed: 677.253 sec

# %%
print len(fs)

import cPickle
# save the classifier
# with open('fs.pkl', 'wb') as fid:
#    cPickle.dump(fs, fid)

# %%
import Image

if TEST:
    COUNT = 20
else:
    COUNT = len(foods)

test_fs = []

orientations = 9
cell = 16
block = 3

####################
# Test phase
####################
foods = test

def get_foods(foods, limit=COUNT):
    bar = pyprind.ProgBar(limit, monitor=True)
    for idx, food in enumerate(foods[:limit]):
        bar.update()
        img = imread(food[0])
        
        try:
            yield color.rgb2gray(img)
        except:
            continue
            
def get_cropped_foods(foods, height, width, limit=COUNT):
    bar = pyprind.ProgBar(limit, monitor=True)
    for idx, food in enumerate(foods[:limit]):
        bar.update()
        img = imread(food[0])
        img = resize_image(img, (height, width))
        
        try:
            yield color.rgb2gray(img)
        except:
            continue

def build_feature_vecture(foods):
    for food in get_cropped_foods(foods, 256, 256):
        f = feature.hog(food,
                        orientations=orientations,
                        pixels_per_cell=(cell, cell),
                        cells_per_block=(block, block))

        test_fs.append((f.ravel()).tolist())

build_feature_vecture(foods)
# Out:
# 0%                          100%
# [                              ]
# [#                             ]
#  | ETA[sec]: 330.192
# [##                            ]
#  | ETA[sec]: 323.869
# [###                           ]
#  | ETA[sec]: 305.627
# [####                          ]
#  | ETA[sec]: 290.026
# [#####                         ]
#  | ETA[sec]: 338.779
# [######                        ]
#  | ETA[sec]: 332.646
# [#######                       ]
#  | ETA[sec]: 316.979
# [########                      ]
#  | ETA[sec]: 301.431
# [#########                     ]
#  | ETA[sec]: 281.442
# [##########                    ]
#  | ETA[sec]: 263.074
# [###########                   ]
#  | ETA[sec]: 249.377
# [############                  ]
#  | ETA[sec]: 242.150
# [#############                 ]
#  | ETA[sec]: 238.618
# [##############                ]
#  | ETA[sec]: 234.057
# [###############               ]
#  | ETA[sec]: 226.811
# [################              ]
#  | ETA[sec]: 213.889
# [#################             ]
#  | ETA[sec]: 203.595
# [##################            ]
#  | ETA[sec]: 189.125
# [###################           ]
#  | ETA[sec]: 173.809
# [####################          ]
#  | ETA[sec]: 158.573
# [#####################         ]
#  | ETA[sec]: 143.209
# [######################        ]
#  | ETA[sec]: 127.379
# [#######################       ]
#  | ETA[sec]: 111.979
# [########################      ]
#  | ETA[sec]: 96.123
# [#########################     ]
#  | ETA[sec]: 79.817
# [##########################    ]
#  | ETA[sec]: 63.753
# [###########################   ]
#  | ETA[sec]: 47.769
# [############################  ]
#  | ETA[sec]: 31.589
# [############################# ]
#  | ETA[sec]: 15.795
# [##############################]
#  | ETA[sec]: 0.000
# [##############################]
#  | ETA[sec]: 0.000
# Total time elapsed: 473.646 sec

# %%
print len(fs)

import cPickle
# save the classifier
# with open('test_fs.pkl', 'wb') as fid:
#    cPickle.dump(fs, fid)
# Out:
# 9174

# %%
import cPickle
with open('svm.pkl', 'rb') as fid:
    fs = cPickle.load(fid)
print len(fs)
# Out:
# 9174

# %%
from sklearn import datasets, svm, metrics, cross_validation

print "Start learning"
start_time = time.time()

clf = svm.SVC(gamma=0.001)
clf.fit(fs, train_labels[:len(fs)])

end_time = time.time()
print "Finished learning"

print("Elapsed time was %g seconds" % (end_time - start_time))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.001, kernel='rbf', max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False)

# %%
import cPickle
# save the classifier
with open('clf.pkl', 'wb') as fid:
    cPickle.dump(clf, fid)

# %%
def classify(clf, img):
    img = resize_image(img, (256, 256))
    img = color.rgb2gray(img)
    
    f = feature.hog(img,
                    orientations=orientations,
                    pixels_per_cell=(cell, cell),
                    cells_per_block=(block, block))

    print clf.predict(f)

f_name = foods[1002][0]
print f_name

img = imread(f_name)

plt.figure(1)
plt.imshow(img)

print "Start predicting"
start_time = time.time()

classify(clf, img)

end_time = time.time()
print "Finished predicting"

print("Elapsed time was %g seconds" % (end_time - start_time))
# Out:
# /home/carpedm20/data/food100/29/2834.jpg
# Start predicting
# [36]
# Finished predicting
# Elapsed time was 0.223248 seconds

# %%
img = imread(foods[0][0])

print img.shape

plt.figure(1)
plt.imshow(img)

plt.figure(2)
plt.imshow(color.rgb2hsv(img))

plt.figure(3)
plt.imshow(hogs[1])
# Out:
# (450, 600, 3)
